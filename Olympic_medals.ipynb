# %%
import pandas as pd

# %%
df = pd.read_csv('olympics_medals_country_wise.csv')

# %%
print(df)
# Out:
#                             countries  ioc_code   summer_participations  \
# 0                          Afghanistan     (AFG)                     15
# 1                              Algeria     (ALG)                     14
# 2                            Argentina     (ARG)                     25
# 3                              Armenia     (ARM)                      7
# 4                          Australasia     (ANZ)                      2
# ..                                 ...       ...                    ...
# 151                             Zambia     (ZAM)                     14
# 152                           Zimbabwe     (ZIM)                     14
# 153       Independent Olympic Athletes     (IOA)                      3
# 154  Independent Olympic Participants      (IOP)                      1
# 155                        Mixed Team      (ZZX)                      3
#
#     summer_gold  summer_silver  summer_bronze summer_total  \
# ...

# %%
df.describe()
# Out:
#        summer_participations  summer_silver  summer_bronze  \
# count             156.000000     156.000000     156.000000
# mean               14.673077      34.782051      37.775641
# std                 7.432417      86.085726      83.157105
# min                 0.000000       0.000000       0.000000
# 25%                 9.750000       1.000000       1.000000
# 50%                15.000000       5.000000       6.000000
# 75%                19.000000      29.250000      31.250000
# max                29.000000     831.000000     738.000000
#
#        winter_participations  winter_gold  winter_silver  winter_bronze  \
# count             156.000000    156.00000     156.000000     156.000000
# mean                7.314103      7.50641       7.487179       7.442308
# std                 7.900024     22.23264      21.431808      20.126773
# min                 0.000000      0.00000       0.000000       0.000000
# ...

# %%
df.columns
# Out:
# Index(['countries ', 'ioc_code ', 'summer_participations', 'summer_gold',
#        'summer_silver', 'summer_bronze', 'summer_total',
#        'winter_participations', 'winter_gold', 'winter_silver',
#        'winter_bronze', 'winter_total', 'total_participation', 'total_gold',
#        'total_silver', 'total_bronze', 'total_total '],
#       dtype='object')

# %%
df.rename(columns={'countries ': 'countries', 'ioc_code ': 'ioc_code', 'total_total ': 'total_total'}, inplace=True)

# %%
df["countries"]
# Out:
# 0                            Afghanistan
# 1                                Algeria
# 2                              Argentina
# 3                                Armenia
# 4                            Australasia
#                      ...
# 151                               Zambia
# 152                             Zimbabwe
# 153         Independent Olympic Athletes
# 154    Independent Olympic Participants
# 155                          Mixed Team
# Name: countries, Length: 156, dtype: object

# %%
df["total_total"].dtypes
# Out:
# dtype('O')

# %%
df["winter_total"].dtypes
# Out:
# dtype('int64')

# %%
df["summer_total"].dtypes
# Out:
# dtype('O')

# %%
df["summer_total"] = df["summer_total"].str.replace(',', '')

# %%
df["summer_total"] = pd.to_numeric(
    df["summer_total"], 
    errors='coerce'
).fillna(0).astype('int')
df["summer_total"].dtypes
# Out:
# dtype('int64')

# %%
df["total_total"]
# Out:
# 0       2
# 1      17
# 2      77
# 3      18
# 4      12
#        ..
# 151     2
# 152     8
# 153     2
# 154     3
# 155    25
# Name: total_total, Length: 156, dtype: int64

# %%
df["total_total"].dtypes
# Out:
# dtype('int64')

# %%
df["total_total"] = pd.to_numeric(
    df["total_total"], 
    errors='coerce'
).fillna(0).astype('int')
df["total_total"].dtypes
# Out:
# dtype('int64')

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df["countries"],df["total_total"])

# %%
### Picking 15 countries by sorting total medals earned
top_achievers = pd.DataFrame()
top_achievers = df.sort_values('total_total', ascending=False).head(15)
top_achievers
# Out:
#          countries ioc_code  summer_participations summer_gold  summer_silver  \
# 144  United States    (USA)                     28       1,060            831
# 110   Soviet Union    (URS)                      9         395            319
# 51   Great Britain    (GBR)                     29         284            318
# 46         Germany    (GER)                     17         201            207
# 43          France    (FRA)                     29         223            251
# 66           Italy    (ITA)                     28         217            188
# 24           China    (CHN)                     11         262            199
# 128         Sweden    (SWE)                     28         148            176
# 68           Japan    (JPN)                     23         169            150
# 97          Norway    (NOR)                     27          62             51
# 5        Australia    (AUS)                     27         164            173
# ...

# %% [markdown]
# ### Visualization 1: Graph for Number of participants per country for Top 15 countries

# %%
plt.figure(figsize=(20,10), dpi=300)
plt.title("Number of Participants per Country")
plt.xlabel("Countries")
plt.ylabel("Participants")
plt.bar(top_achievers["countries"],top_achievers["total_participation"])
# Out:
# <BarContainer object of 15 artists>

# %%
top_achievers.plot(kind="bar")
plt.title("Total Medals for Top 15 Countries")
plt.xlabel("Countries")
plt.ylabel("Total Medals")
# Out:
# Text(0, 0.5, 'Total Medals')

# %%
top_achievers = top_achievers.set_index('countries')
top_achievers.plot(kind="bar")
plt.title("Total Medals for Top 15 Countries")
plt.xlabel("Countries")
plt.ylabel("Total Medals")
# Out:
# Text(0, 0.5, 'Total Medals')

# %%
plotData = top_achievers[['summer_total' , 'total_total', 'winter_total']].copy()

plotData
# Out:
#                summer_total  total_total  winter_total
# countries
# United States          2629         2959           330
# Soviet Union           1010         1204           194
# Great Britain           916          950            34
# Germany                 655          922           267
# France                  751          889           138
# Italy                   618          759           141
# China                   634          711            77
# Sweden                  503          679           176
# Japan                   497          573            76
# Norway                  163          568           405
# Australia               547          566            19
# Canada                  326          551           225
# Russia                  425          546           121
# Hungary                 511          521            10
# East Germany            409          519           110

# %% [markdown]
# ### Visualization 2: Graph representing total medal won by each of the top 15 countries ( Total, Summer & Winter )

# %%
plotdata.head()
plotData.plot(kind="bar")
plt.title("Total Medals for Top 15 Countries")
plt.xlabel("Countries")
plt.ylabel("Total Medals")
# Out:
# Text(0, 0.5, 'Total Medals')
